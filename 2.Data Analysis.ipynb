# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the data
data=pd.read_csv("clean_data.csv")
data
# Out:
#      Shipment_ID  Distance_km    Weight_kg Mode_of_Transport     Origin  \
# 0      SHIP00001       2588.5  1341.000000              Rail    Kolkata
# 1      SHIP00002       3822.0  3538.000000               Sea    Kolkata
# 2      SHIP00003       3142.0  4777.000000              Road    Chennai
# 3      SHIP00004        516.0  3704.000000               Air    Chennai
# 4      SHIP00005       4476.0   578.000000               Sea     Mumbai
# ...          ...          ...          ...               ...        ...
# 9995   SHIP09996        284.0   633.000000               Air  Bangalore
# 9996   SHIP09997       2588.5  2859.000000              Rail    Kolkata
# 9997   SHIP09998       1958.0   705.000000               Air    Chennai
# 9998   SHIP09999       1467.0  4931.000000              Rail    Kolkata
# 9999   SHIP10000       4969.0  2495.039895              Road    Chennai
#
#       Destination  Fuel_Price_per_Liter  Demand_Fluctuation  \
# 0          London                  1.89            1.042210
# 1     Los Angeles                  0.75            1.075883
# 2          London                  1.99            1.170771
# 3           Dubai                  1.58            1.129244
# 4           Dubai                  1.26            0.998045
# ...           ...                   ...                 ...
# 9995  Los Angeles                  0.52            0.977983
# 9996  Los Angeles                  1.39            1.091401
# 9997     New York                  1.26            0.971334
# 9998    Singapore                  1.56            0.973844
# 9999        Dubai                  1.20            1.058222
#
#      Traffic_Conditions  Warehouse_Processing_Time  Customs_Clearance_Delay  \
# 0                Medium                          8                        2
# 1                  High                          8                        3
# 2                   Low                          3                        2
# 3                   Low                          8                        3
# 4                  High                          5                        4
# ...                 ...                        ...                      ...
# 9995             Medium                          2                        4
# 9996             Medium                          8                        1
# 9997             Medium                          8                        1
# 9998               High                          1                        1
# 9999               High                          7                        1
#
#       Packaging_Cost  Freight_Insurance_Cost  Freight_Cost_USD
# 0             326.35                  969.69        818.740237
# 1             293.82                  649.12        676.720000
# 2              52.03                  150.30       1288.520000
# 3             421.87                  181.12       1267.500000
# 4             428.14                  615.63        463.680000
# ...              ...                     ...               ...
# 9995          309.59                  739.37         91.620000
# 9996          192.02                  386.04        472.500000
# 9997          125.19                  323.12        599.220000
# 9998          107.21                  489.50        716.910000
# 9999          209.60                  854.02        648.270000
#
# [10000 rows x 14 columns]

# %%
data.columns
# Out:
# Index(['Shipment_ID', 'Distance_km', 'Weight_kg', 'Mode_of_Transport',
#        'Origin', 'Destination', 'Fuel_Price_per_Liter', 'Demand_Fluctuation',
#        'Traffic_Conditions', 'Warehouse_Processing_Time',
#        'Customs_Clearance_Delay', 'Packaging_Cost', 'Freight_Insurance_Cost',
#        'Freight_Cost_USD'],
#       dtype='object')

# %%
import seaborn as sns
sns.boxplot(data['Freight_Cost_USD'])

# %%
data
# Out:
#      Shipment_ID  Distance_km    Weight_kg Mode_of_Transport     Origin  \
# 0      SHIP00001       2588.5  1341.000000              Rail    Kolkata
# 1      SHIP00002       3822.0  3538.000000               Sea    Kolkata
# 2      SHIP00003       3142.0  4777.000000              Road    Chennai
# 3      SHIP00004        516.0  3704.000000               Air    Chennai
# 4      SHIP00005       4476.0   578.000000               Sea     Mumbai
# ...          ...          ...          ...               ...        ...
# 9995   SHIP09996        284.0   633.000000               Air  Bangalore
# 9996   SHIP09997       2588.5  2859.000000              Rail    Kolkata
# 9997   SHIP09998       1958.0   705.000000               Air    Chennai
# 9998   SHIP09999       1467.0  4931.000000              Rail    Kolkata
# 9999   SHIP10000       4969.0  2495.039895              Road    Chennai
#
#       Destination  Fuel_Price_per_Liter  Demand_Fluctuation  \
# 0          London                  1.89            1.042210
# 1     Los Angeles                  0.75            1.075883
# 2          London                  1.99            1.170771
# 3           Dubai                  1.58            1.129244
# 4           Dubai                  1.26            0.998045
# ...           ...                   ...                 ...
# 9995  Los Angeles                  0.52            0.977983
# 9996  Los Angeles                  1.39            1.091401
# 9997     New York                  1.26            0.971334
# 9998    Singapore                  1.56            0.973844
# 9999        Dubai                  1.20            1.058222
#
#      Traffic_Conditions  Warehouse_Processing_Time  Customs_Clearance_Delay  \
# 0                Medium                          8                        2
# 1                  High                          8                        3
# 2                   Low                          3                        2
# 3                   Low                          8                        3
# 4                  High                          5                        4
# ...                 ...                        ...                      ...
# 9995             Medium                          2                        4
# 9996             Medium                          8                        1
# 9997             Medium                          8                        1
# 9998               High                          1                        1
# 9999               High                          7                        1
#
#       Packaging_Cost  Freight_Insurance_Cost  Freight_Cost_USD
# 0             326.35                  969.69        818.740237
# 1             293.82                  649.12        676.720000
# 2              52.03                  150.30       1288.520000
# 3             421.87                  181.12       1267.500000
# 4             428.14                  615.63        463.680000
# ...              ...                     ...               ...
# 9995          309.59                  739.37         91.620000
# 9996          192.02                  386.04        472.500000
# 9997          125.19                  323.12        599.220000
# 9998          107.21                  489.50        716.910000
# 9999          209.60                  854.02        648.270000
#
# [10000 rows x 14 columns]

# %%
data.head()
# Out:
#   Shipment_ID  Distance_km  Weight_kg Mode_of_Transport   Origin  Destination  \
# 0   SHIP00001       2588.5     1341.0              Rail  Kolkata       London
# 1   SHIP00002       3822.0     3538.0               Sea  Kolkata  Los Angeles
# 2   SHIP00003       3142.0     4777.0              Road  Chennai       London
# 3   SHIP00004        516.0     3704.0               Air  Chennai        Dubai
# 4   SHIP00005       4476.0      578.0               Sea   Mumbai        Dubai
#
#    Fuel_Price_per_Liter  Demand_Fluctuation Traffic_Conditions  \
# 0                  1.89            1.042210             Medium
# 1                  0.75            1.075883               High
# 2                  1.99            1.170771                Low
# 3                  1.58            1.129244                Low
# 4                  1.26            0.998045               High
#
#    Warehouse_Processing_Time  Customs_Clearance_Delay  Packaging_Cost  \
# 0                          8                        2          326.35
# 1                          8                        3          293.82
# 2                          3                        2           52.03
# 3                          8                        3          421.87
# 4                          5                        4          428.14
#
#    Freight_Insurance_Cost  Freight_Cost_USD
# 0                  969.69        818.740237
# 1                  649.12        676.720000
# 2                  150.30       1288.520000
# 3                  181.12       1267.500000
# 4                  615.63        463.680000

# %%
data.isna().sum()
# Out:
# Shipment_ID                  0
# Distance_km                  0
# Weight_kg                    0
# Mode_of_Transport            0
# Origin                       0
# Destination                  0
# Fuel_Price_per_Liter         0
# Demand_Fluctuation           0
# Traffic_Conditions           0
# Warehouse_Processing_Time    0
# Customs_Clearance_Delay      0
# Packaging_Cost               0
# Freight_Insurance_Cost       0
# Freight_Cost_USD             0
# dtype: int64

# %%
def quanqual(dataset):
    quan = []
    qual = []
    for ColumnName in dataset.columns:
        if dataset[ColumnName].dtype == 'O':  
            qual.append(ColumnName)
        else:
            quan.append(ColumnName) 
    return quan,qual

# %%
quan,qual=quanqual(data)

# %%
quan
# Out:
# ['Distance_km',
#  'Weight_kg',
#  'Fuel_Price_per_Liter',
#  'Demand_Fluctuation',
#  'Warehouse_Processing_Time',
#  'Customs_Clearance_Delay',
#  'Packaging_Cost',
#  'Freight_Insurance_Cost',
#  'Freight_Cost_USD']

# %%
qual
# Out:
# ['Shipment_ID',
#  'Mode_of_Transport',
#  'Origin',
#  'Destination',
#  'Traffic_Conditions']

# %%
descriptive = pd.DataFrame(index=['mean','median','mode','Q1:25%','Q2:50%','Q3:75%','Q4:100%','IQR','1.5rule','lesser','greater','min','max'], columns=quan)

# Assuming 'dataset' is your DataFrame
for ColumnName in quan:
    descriptive.loc['mean', ColumnName] = data[ColumnName].mean()
    descriptive.loc['median', ColumnName] = data[ColumnName].median()
    descriptive.loc['mode', ColumnName] = data[ColumnName].mode()[0]
    descriptive.loc['Q1:25%', ColumnName] = data[ColumnName].quantile(0.25)
    descriptive.loc['Q2:50%', ColumnName] = data[ColumnName].quantile(0.50)
    descriptive.loc['Q3:75%', ColumnName] = data[ColumnName].quantile(0.75)
    descriptive.loc['99%', ColumnName] = np.percentile(data[ColumnName], 99)
    descriptive.loc['Q4:100%', ColumnName] = data[ColumnName].max()
    descriptive.loc['IQR', ColumnName] = descriptive.loc['Q3:75%', ColumnName] - descriptive.loc['Q1:25%', ColumnName]
    descriptive.loc['1.5rule', ColumnName] = 1.5 * descriptive.loc['IQR', ColumnName]
    descriptive.loc['lesser', ColumnName] = descriptive.loc['Q1:25%', ColumnName] - descriptive.loc['1.5rule', ColumnName]
    descriptive.loc['greater', ColumnName] = descriptive.loc['Q3:75%', ColumnName] + descriptive.loc['1.5rule', ColumnName]
    descriptive.loc['min', ColumnName] = data[ColumnName].min()
    descriptive.loc['max', ColumnName] = data[ColumnName].max()

descriptive
# Out:
#         Distance_km    Weight_kg Fuel_Price_per_Liter Demand_Fluctuation  \
# mean      2557.5948  2495.039895             1.256455           1.001966
# median       2588.5  2495.039895                 1.26           1.002316
# mode         2588.5  2495.039895                 1.26           0.800052
# Q1:25%       1366.0       1324.0                  0.9           0.902636
# Q2:50%       2588.5  2495.039895                 1.26           1.002316
# Q3:75%       3727.5      3644.25                 1.61           1.102649
# Q4:100%      4998.0       4999.0                  2.0           1.199945
# IQR          2361.5      2320.25                 0.71           0.200013
# 1.5rule     3542.25     3480.375                1.065           0.300019
# lesser     -2176.25    -2156.375               -0.165           0.602617
# greater     7269.75     7124.625                2.675           1.402668
# min            51.0         50.0                  0.5           0.800052
# max          4998.0       4999.0                  2.0           1.199945
# 99%          4961.0      4955.01                 1.98           1.195042
#
#         Warehouse_Processing_Time Customs_Clearance_Delay Packaging_Cost  \
# mean                       4.9789                  1.9866     255.671338
# median                        5.0                     2.0         257.35
# mode                            1                       0          73.53
# Q1:25%                        3.0                     1.0       132.7775
# Q2:50%                        5.0                     2.0         257.35
# Q3:75%                        7.0                     3.0        375.425
# Q4:100%                         9                       4         499.96
# IQR                           4.0                     2.0       242.6475
# 1.5rule                       6.0                     3.0      363.97125
# lesser                       -3.0                    -2.0     -231.19375
# greater                      13.0                     6.0      739.39625
# min                             1                       0          10.16
# max                             9                       4         499.96
# 99%                           9.0                     4.0         495.29
#
#         Freight_Insurance_Cost Freight_Cost_USD
# mean                524.575038       769.160967
# median                  525.07          664.565
# mode                     85.05       1951.27375
# Q1:25%                 287.195           380.93
# Q2:50%                  525.07          664.565
# Q3:75%                759.5625        1009.0675
# Q4:100%                 999.92       1951.27375
# IQR                   472.3675         628.1375
# 1.5rule              708.55125        942.20625
# lesser              -421.35625       -561.27625
# greater             1468.11375       1951.27375
# min                      50.22             9.72
# max                     999.92       1951.27375
# 99%                   990.5142       1951.27375

# %%
lesser=[]
greater=[]

for columnName in quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName] ["max"]>descriptive[columnName]["greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %% [markdown]
# #  Statistical Summary

# %%
def freqTable(columnName,data):
    freqTable=pd.DataFrame(columns=['unique_values','frequency','Relative frequency','cusum'])
    freqTable['unique_values']=data[columnName].value_counts().index
    freqTable['frequency']=data[columnName].value_counts().values
    freqTable['Relative frequency']=(freqTable['frequency']/103)
    freqTable['cusum']=freqTable['Relative frequency'].cumsum()
    return freqTable

# %%
freqTable('Freight_Cost_USD',data)
# Out:
#       unique_values  frequency  Relative frequency      cusum
# 0       1951.273750        647            6.281553   6.281553
# 1        818.740237        500            4.854369  11.135922
# 2        183.800000          3            0.029126  11.165049
# 3        485.580000          3            0.029126  11.194175
# 4        333.230000          3            0.029126  11.223301
# ...             ...        ...                 ...        ...
# 8566     498.190000          1            0.009709  97.048544
# 8567     794.180000          1            0.009709  97.058252
# 8568     844.140000          1            0.009709  97.067961
# 8569     864.980000          1            0.009709  97.077670
# 8570     648.270000          1            0.009709  97.087379
#
# [8571 rows x 4 columns]

# %%
freqTable('Weight_kg',data)
# Out:
#       unique_values  frequency  Relative frequency      cusum
# 0       2495.039895        500            4.854369   4.854369
# 1        160.000000          8            0.077670   4.932039
# 2         77.000000          8            0.077670   5.009709
# 3        999.000000          8            0.077670   5.087379
# 4        998.000000          8            0.077670   5.165049
# ...             ...        ...                 ...        ...
# 4251    4643.000000          1            0.009709  97.048544
# 4252    4942.000000          1            0.009709  97.058252
# 4253    1692.000000          1            0.009709  97.067961
# 4254     102.000000          1            0.009709  97.077670
# 4255     705.000000          1            0.009709  97.087379
#
# [4256 rows x 4 columns]

# %% [markdown]
# # Basic Univariate Analysis

# %%
data.columns
# Out:
# Index(['Shipment_ID', 'Distance_km', 'Weight_kg', 'Mode_of_Transport',
#        'Origin', 'Destination', 'Fuel_Price_per_Liter', 'Demand_Fluctuation',
#        'Traffic_Conditions', 'Warehouse_Processing_Time',
#        'Customs_Clearance_Delay', 'Packaging_Cost', 'Freight_Insurance_Cost',
#        'Freight_Cost_USD'],
#       dtype='object')

# %%
from scipy import stats

# %%
cost=data['Freight_Cost_USD']
cost
# Out:
# 0        818.740237
# 1        676.720000
# 2       1288.520000
# 3       1267.500000
# 4        463.680000
#            ...
# 9995      91.620000
# 9996     472.500000
# 9997     599.220000
# 9998     716.910000
# 9999     648.270000
# Name: Freight_Cost_USD, Length: 10000, dtype: float64

# %%
meanc=cost.mean()
medianc=cost.median()
modec=cost.mode().iloc[0]
skewc=stats.skew(cost)
kurtosis=stats.kurtosis(cost)
std=cost.std()
variance=cost.var()

# %%
print("Mean Value",meanc)
print("Median Value",medianc)
print("Mode Value",modec)
print("Skewness Value",skewc)
print("kurtosis Value",kurtosis)
print("Standard Deviation Value",std)
print("Variance value",variance)
# Out:
# Mean Value 769.1609672383646
# Median Value 664.565
# Mode Value 1951.27375
# Skewness Value 0.9426076348035347
# kurtosis Value 0.10989265558225014
# Standard Deviation Value 505.6376973096976
# Variance value 255669.4809406534

# %% [markdown]
# # As the kurtosis is less than it is platykurtic

# %%
import seaborn as sns

# %%
fig, axes = plt.subplots(1,2, figsize=(14, 6))
sns.histplot(cost, bins=10, kde=True, ax=axes[0], color='green')
axes[0].axvline(meanc, color='red', linestyle='--', label='Mean')
axes[0].axvline(medianc, color='green', linestyle='--', label='Median')
axes[0].axvline(modec, color='purple', linestyle='--', label='Mode')
axes[0].set_title(f'Cost History \nSkewness: {skewc:.2f}')
axes[0].set_xlabel('Cost')
axes[0].set_ylabel('Frequency')
axes[0].legend()

sns.histplot(cost, bins=10, kde=True, ax=axes[1], color='skyblue')
axes[1].axvline(meanc, color='red', linestyle='--', label='Mean')
axes[1].axvline(medianc, color='green', linestyle='--', label='Median')
axes[1].axvline(modec, color='purple', linestyle='--', label='Mode')
axes[1].set_title(f'Cost history \nKurtosis: {kurtosis:.2f}')
axes[1].set_xlabel('cost')
axes[1].set_ylabel('Frequency')
axes[1].legend()

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# #   Normal Distribution

# %%
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(cost, bins=10, kde=False, color='skyblue', stat="density", alpha=0.6)

# Generate the x values for the normal distribution curve
x = np.linspace(cost.min(), cost.max(), 100)
# Calculate the normal distribution curve
y = stats.norm.pdf(x, meanc, std)

# Plot the normal distribution curve
plt.plot(x, y, color='red', label='Normal Distribution', linewidth=2)

# Add titles and labels
plt.title('Normal Distribution of Revenue ')
plt.xlabel('Cost')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Check lowest and Highest cost

# %%
# Lowest cost
low_cost = data['Freight_Cost_USD'].min()
print("Lowest cost Value:", low_cost)

# Highest cost
high_cost = data['Freight_Cost_USD'].max()
print("Highest cost Value:", high_cost)
# Out:
# Lowest cost Value: 9.72
# Highest cost Value: 1951.27375

# %% [markdown]
# # Probability Density Function

# %%
# Define the range for filtering
lower_bound = 500
upper_bound = 1000

# Calculate the percentage of values within the specified range
filtered_data = cost[(cost >= lower_bound) & (cost <= upper_bound)]
percentage_in_range = (len(filtered_data) / len(cost)) * 100

sns.set(style="whitegrid")

# Create the figure for KDE
plt.figure(figsize=(10, 6))

# Plot the KDE for the Probability Density Function in the specified range
sns.kdeplot(cost, color='blue', fill=True, alpha=0.3, label='Overall Distribution')
sns.kdeplot(filtered_data, color='orange', fill=True, alpha=0.6, label='Filtered Range (7k to 10k)')

# Add vertical lines for the range
plt.axvline(lower_bound, color='green', linestyle='--', label='Lower Bound (60)')
plt.axvline(upper_bound, color='red', linestyle='--', label='Upper Bound (70)')

# Add titles and labels
plt.title('Probability Density Function of cost with Range Highlight')
plt.xlabel('cost')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a bar plot for percentage representation
plt.figure(figsize=(6, 4))
plt.bar(['Within 0-50', 'Outside 50-100'], [percentage_in_range, 100 - percentage_in_range], color=['orange', 'lightblue'])
plt.title('Percentage of cost  in Range (60 to 70)')
plt.ylabel('Percentage')
plt.ylim(0, 100)

# Show the percentage value on top of the bars
for index, value in enumerate([percentage_in_range, 100 - percentage_in_range]):
    plt.text(index, value + 1, f'{value:.2f}%', ha='center')

# Show the bar plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Standard Normal Distribution

# %%
from scipy.stats import norm

mean = np.mean(cost)
std_dev = np.std(cost)

# Standardize the  ratings
standardized_data = (cost - mean) / std_dev

# Create a range of values for plotting the standard normal distribution
x_values = np.linspace(-4, 4, 100)  # Range for the standard normal distribution
y_values = norm.pdf(x_values, 0, 1)  # PDF for standard normal distribution

# Set the style for the plots
sns.set(style="whitegrid")

# Create the figure
plt.figure(figsize=(10, 6))

# Plot the standardized data's histogram
sns.histplot(standardized_data, bins=10, kde=True, color='skyblue', stat='density', label='Standardized revenue')

# Plot the standard normal distribution curve
plt.plot(x_values, y_values, color='red', label='Standard Normal Distribution', lw=2)

# Add titles and labels
plt.title('Standard Normal Distribution of revenue')
plt.xlabel('Standardized revenue')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
# Cost distribution
sns.histplot(data['Freight_Cost_USD'], kde=True, bins=10)
plt.title('Cost Distribution')
plt.xlabel('cost')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# #  Covariance

# %%
data.cov()
# Out:
#                             Distance_km     Weight_kg  Fuel_Price_per_Liter  \
# Distance_km                1.938748e+06 -1.879766e+01              6.386381
# Weight_kg                 -1.879766e+01  1.931903e+06             -3.384595
# Fuel_Price_per_Liter       6.386381e+00 -3.384595e+00              0.178665
# Demand_Fluctuation         4.878517e-01 -2.284398e+00             -0.000332
# Warehouse_Processing_Time -1.934903e+01  2.149974e+01             -0.013975
# Customs_Clearance_Delay   -2.491779e+00  3.213447e+01             -0.009069
# Packaging_Cost             1.260865e+03 -9.224352e+02             -0.163781
# Freight_Insurance_Cost     9.701271e+01  4.268081e+02             -0.630511
# Freight_Cost_USD           3.350944e+05  1.620168e+05             90.223893
#
#                            Demand_Fluctuation  Warehouse_Processing_Time  \
# Distance_km                          0.487852                 -19.349035
# Weight_kg                           -2.284398                  21.499745
# Fuel_Price_per_Liter                -0.000332                  -0.013975
# Demand_Fluctuation                   0.013256                   0.003800
# Warehouse_Processing_Time            0.003800                   6.729128
# Customs_Clearance_Delay             -0.000591                  -0.000583
# Packaging_Cost                       0.130760                  -4.026167
# Freight_Insurance_Cost               0.065941                  12.396569
# Freight_Cost_USD                     8.096570                   7.303799
#
#                            Customs_Clearance_Delay  Packaging_Cost  \
# Distance_km                              -2.491779     1260.865170
# Weight_kg                                32.134472     -922.435212
# Fuel_Price_per_Liter                     -0.009069       -0.163781
# Demand_Fluctuation                       -0.000591        0.130760
# Warehouse_Processing_Time                -0.000583       -4.026167
# Customs_Clearance_Delay                   2.022023       -3.009100
# Packaging_Cost                           -3.009100    19884.510531
# Freight_Insurance_Cost                    4.369690     -123.677294
# Freight_Cost_USD                        -11.709500      412.910730
#
#                            Freight_Insurance_Cost  Freight_Cost_USD
# Distance_km                             97.012713     335094.377353
# Weight_kg                              426.808090     162016.831521
# Fuel_Price_per_Liter                    -0.630511         90.223893
# Demand_Fluctuation                       0.065941          8.096570
# Warehouse_Processing_Time               12.396569          7.303799
# Customs_Clearance_Delay                  4.369690        -11.709500
# Packaging_Cost                        -123.677294        412.910730
# Freight_Insurance_Cost               75054.038921        767.826719
# Freight_Cost_USD                       767.826719     255669.480941

# %% [markdown]
# # Covarelation

# %%
# Select only numeric columns
data.corr()
# Out:
#                            Distance_km  Weight_kg  Fuel_Price_per_Liter  \
# Distance_km                   1.000000  -0.000010              0.010851
# Weight_kg                    -0.000010   1.000000             -0.005761
# Fuel_Price_per_Liter          0.010851  -0.005761              1.000000
# Demand_Fluctuation            0.003043  -0.014275             -0.006812
# Warehouse_Processing_Time    -0.005357   0.005963             -0.012746
# Customs_Clearance_Delay      -0.001259   0.016259             -0.015089
# Packaging_Cost                0.006422  -0.004706             -0.002748
# Freight_Insurance_Cost        0.000254   0.001121             -0.005445
# Freight_Cost_USD              0.475956   0.230530              0.422146
#
#                            Demand_Fluctuation  Warehouse_Processing_Time  \
# Distance_km                          0.003043                  -0.005357
# Weight_kg                           -0.014275                   0.005963
# Fuel_Price_per_Liter                -0.006812                  -0.012746
# Demand_Fluctuation                   1.000000                   0.012723
# Warehouse_Processing_Time            0.012723                   1.000000
# Customs_Clearance_Delay             -0.003613                  -0.000158
# Packaging_Cost                       0.008054                  -0.011007
# Freight_Insurance_Cost               0.002091                   0.017444
# Freight_Cost_USD                     0.139077                   0.005568
#
#                            Customs_Clearance_Delay  Packaging_Cost  \
# Distance_km                              -0.001259        0.006422
# Weight_kg                                 0.016259       -0.004706
# Fuel_Price_per_Liter                     -0.015089       -0.002748
# Demand_Fluctuation                       -0.003613        0.008054
# Warehouse_Processing_Time                -0.000158       -0.011007
# Customs_Clearance_Delay                   1.000000       -0.015007
# Packaging_Cost                           -0.015007        1.000000
# Freight_Insurance_Cost                    0.011217       -0.003201
# Freight_Cost_USD                         -0.016286        0.005791
#
#                            Freight_Insurance_Cost  Freight_Cost_USD
# Distance_km                              0.000254          0.475956
# Weight_kg                                0.001121          0.230530
# Fuel_Price_per_Liter                    -0.005445          0.422146
# Demand_Fluctuation                       0.002091          0.139077
# Warehouse_Processing_Time                0.017444          0.005568
# Customs_Clearance_Delay                  0.011217         -0.016286
# Packaging_Cost                          -0.003201          0.005791
# Freight_Insurance_Cost                   1.000000          0.005543
# Freight_Cost_USD                         0.005543          1.000000

# %% [markdown]
# # Test the Analysis of Variance between Freight cost and Packing cost at signifance level 5%.(Make decision using Hypothesis Testing)

# %% [markdown]
# The p-value from the result is 0 which is much smaller than 0.05.
#
# A p-value smaller than the significance level (commonly 0.05) means the null hypothesis (H₀) is rejected, and the alternative hypothesis (H₁) is accepted.
#
# Correct Interpretation: Since the p-value is much smaller than 0.05, we reject the null hypothesis (H₀). Conclusion: There is a significant difference between etest_p and mba_p.

# %%
#ANOVA - Analysis of Variance -One way classification
import scipy.stats as stats
stats.f_oneway(data["Freight_Cost_USD"],data["Packaging_Cost"])
# Out:
# F_onewayResult(statistic=9568.781708709317, pvalue=0.0)

# %% [markdown]
# # What Kind of relation between Freight cost and Weight?

# %% [markdown]
# The relationship between Freight cost and Weight is 0.23 which is a positive correlation when the weight increases Freight cost  also increases

# %% [markdown]
# # Which parameter is highly correlated with Freight Cost?

# %% [markdown]
# Weight(Kilogram) is highly correlated with Freight cost by 68%

# %%
# Correlation heatmap for numerical columns
numerical_cols = ['Distance_km', 'Weight_kg', 'Fuel_Price_per_Liter', 'Demand_Fluctuation', 'Warehouse_Processing_Time',
 'Customs_Clearance_Delay', 'Packaging_Cost', 'Freight_Insurance_Cost', 'Freight_Cost_USD']

corr_matrix = data[numerical_cols].corr()

plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title('Correlation Matrix')
plt.show()

# %%
import seaborn as sns
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Shipment_ID', 'Distance_km', 'Weight_kg', 'Mode_of_Transport',
#        'Origin', 'Destination', 'Fuel_Price_per_Liter', 'Demand_Fluctuation',
#        'Traffic_Conditions', 'Warehouse_Processing_Time',
#        'Customs_Clearance_Delay', 'Packaging_Cost', 'Freight_Insurance_Cost',
#        'Freight_Cost_USD'],
#       dtype='object')

# %%
# Average cost by mode of transport
transport_cost = data.groupby('Mode_of_Transport')['Freight_Cost_USD'].mean().sort_values(ascending=False).head(10)
print(transport_cost)

# Plot
transport_cost.plot(kind='bar', color='pink')
plt.title('Mode of Transport')
plt.xlabel('Mode')
plt.ylabel('Average cost')
plt.show()
# Out:
# Mode_of_Transport
# Air     1252.754268
# Sea      737.838263
# Rail     585.631575
# Road     509.984269
# Name: Freight_Cost_USD, dtype: float64
