# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the data
data=pd.read_csv("clean_data.csv")
data
# Out:
#              Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0      Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1            Vietnam   PMO - US  Direct Drop              EXW           Air
# 2      Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3            Vietnam   PMO - US  Direct Drop              EXW           Air
# 4            Vietnam   PMO - US  Direct Drop              EXW           Air
# ...              ...        ...          ...              ...           ...
# 10319       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10320  Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 10321         Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 10322       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10323       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
#       Product Group  Unit of Measure (Per Pack)  Line Item Quantity  \
# 0              HRDT                          30              19.000
# 1               ARV                         180            1000.000
# 2              HRDT                         100             500.000
# 3               ARV                          60           31920.000
# 4               ARV                          60           38000.000
# ...             ...                         ...                 ...
# 10319           ARV                          60           41987.375
# 10320           ARV                          60           21072.000
# 10321           ARV                          30           41987.375
# 10322           ARV                          60           17465.000
# 10323           ARV                          60           36639.000
#
#        Line Item Value  Pack Price  Unit Price First Line Designation  \
# 0            551.00000    29.00000        0.97                    Yes
# 1           6200.00000     6.20000        0.03                    Yes
# 2          40000.00000    52.80125        0.80                    Yes
# 3         127360.80000     3.99000        0.07                    Yes
# 4         121600.00000     3.20000        0.05                    Yes
# ...                ...         ...         ...                    ...
# 10319     409645.96125     3.60000        0.06                     No
# 10320     137389.44000     6.52000        0.11                     No
# 10321     409645.96125     9.99000        0.33                     No
# 10322     113871.80000     6.52000        0.11                    Yes
# 10323      72911.61000     1.99000        0.03                     No
#
#        Weight (Kilograms)  Freight Cost (USD)  Line Item Insurance (USD)  \
# 0                   13.00           780.34000                      47.04
# 1                  358.00          4521.50000                      47.04
# 2                  171.00          1653.78000                      47.04
# 3                 1855.00         12783.38875                      47.04
# 4                 3065.75         12783.38875                      47.04
# ...                   ...                 ...                        ...
# 10319             1047.00          5869.65500                     593.83
# 10320             1047.00          5869.65500                     161.71
# 10321             1047.00          5869.65500                     593.83
# 10322             1392.00          5869.65500                     134.03
# 10323             1047.00          5869.65500                      85.82
#
#        Country_Encoded
# 0                    9
# 1                   40
# 2                    9
# 3                   40
# 4                   40
# ...                ...
# 10319               42
# 10320                9
# 10321               41
# 10322               42
# 10323               42
#
# [10324 rows x 16 columns]

# %%
data.columns
# Out:
# Index(['Country', 'Managed By', 'Fulfill Via', 'Vendor INCO Term',
#        'Shipment Mode', 'Product Group', 'Unit of Measure (Per Pack)',
#        'Line Item Quantity', 'Line Item Value', 'Pack Price', 'Unit Price',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)', 'Country_Encoded'],
#       dtype='object')

# %%
data
# Out:
#              Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0      Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1            Vietnam   PMO - US  Direct Drop              EXW           Air
# 2      Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3            Vietnam   PMO - US  Direct Drop              EXW           Air
# 4            Vietnam   PMO - US  Direct Drop              EXW           Air
# ...              ...        ...          ...              ...           ...
# 10319       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10320  Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 10321         Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 10322       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10323       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
#       Product Group  Unit of Measure (Per Pack)  Line Item Quantity  \
# 0              HRDT                          30              19.000
# 1               ARV                         180            1000.000
# 2              HRDT                         100             500.000
# 3               ARV                          60           31920.000
# 4               ARV                          60           38000.000
# ...             ...                         ...                 ...
# 10319           ARV                          60           41987.375
# 10320           ARV                          60           21072.000
# 10321           ARV                          30           41987.375
# 10322           ARV                          60           17465.000
# 10323           ARV                          60           36639.000
#
#        Line Item Value  Pack Price  Unit Price First Line Designation  \
# 0            551.00000    29.00000        0.97                    Yes
# 1           6200.00000     6.20000        0.03                    Yes
# 2          40000.00000    52.80125        0.80                    Yes
# 3         127360.80000     3.99000        0.07                    Yes
# 4         121600.00000     3.20000        0.05                    Yes
# ...                ...         ...         ...                    ...
# 10319     409645.96125     3.60000        0.06                     No
# 10320     137389.44000     6.52000        0.11                     No
# 10321     409645.96125     9.99000        0.33                     No
# 10322     113871.80000     6.52000        0.11                    Yes
# 10323      72911.61000     1.99000        0.03                     No
#
#        Weight (Kilograms)  Freight Cost (USD)  Line Item Insurance (USD)  \
# 0                   13.00           780.34000                      47.04
# 1                  358.00          4521.50000                      47.04
# 2                  171.00          1653.78000                      47.04
# 3                 1855.00         12783.38875                      47.04
# 4                 3065.75         12783.38875                      47.04
# ...                   ...                 ...                        ...
# 10319             1047.00          5869.65500                     593.83
# 10320             1047.00          5869.65500                     161.71
# 10321             1047.00          5869.65500                     593.83
# 10322             1392.00          5869.65500                     134.03
# 10323             1047.00          5869.65500                      85.82
#
#        Country_Encoded
# 0                    9
# 1                   40
# 2                    9
# 3                   40
# 4                   40
# ...                ...
# 10319               42
# 10320                9
# 10321               41
# 10322               42
# 10323               42
#
# [10324 rows x 16 columns]

# %%
data.head()
# Out:
#          Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0  Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1        Vietnam   PMO - US  Direct Drop              EXW           Air
# 2  Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3        Vietnam   PMO - US  Direct Drop              EXW           Air
# 4        Vietnam   PMO - US  Direct Drop              EXW           Air
#
#   Product Group  Unit of Measure (Per Pack)  Line Item Quantity  \
# 0          HRDT                          30                19.0
# 1           ARV                         180              1000.0
# 2          HRDT                         100               500.0
# 3           ARV                          60             31920.0
# 4           ARV                          60             38000.0
#
#    Line Item Value  Pack Price  Unit Price First Line Designation  \
# 0            551.0    29.00000        0.97                    Yes
# 1           6200.0     6.20000        0.03                    Yes
# 2          40000.0    52.80125        0.80                    Yes
# 3         127360.8     3.99000        0.07                    Yes
# 4         121600.0     3.20000        0.05                    Yes
#
#    Weight (Kilograms)  Freight Cost (USD)  Line Item Insurance (USD)  \
# 0               13.00           780.34000                      47.04
# 1              358.00          4521.50000                      47.04
# 2              171.00          1653.78000                      47.04
# 3             1855.00         12783.38875                      47.04
# 4             3065.75         12783.38875                      47.04
#
#    Country_Encoded
# 0                9
# 1               40
# 2                9
# 3               40
# 4               40

# %%
data.isna().sum()
# Out:
# Country                       0
# Managed By                    0
# Fulfill Via                   0
# Vendor INCO Term              0
# Shipment Mode                 0
# Product Group                 0
# Unit of Measure (Per Pack)    0
# Line Item Quantity            0
# Line Item Value               0
# Pack Price                    0
# Unit Price                    0
# First Line Designation        0
# Weight (Kilograms)            0
# Freight Cost (USD)            0
# Line Item Insurance (USD)     0
# Country_Encoded               0
# dtype: int64

# %%
def quanqual(dataset):
    quan = []
    qual = []
    for ColumnName in dataset.columns:
        if dataset[ColumnName].dtype == 'O':  
            qual.append(ColumnName)
        else:
            quan.append(ColumnName) 
    return quan,qual

# %%
quan,qual=quanqual(data)

# %%
quan
# Out:
# ['Unit of Measure (Per Pack)',
#  'Line Item Quantity',
#  'Line Item Value',
#  'Pack Price',
#  'Unit Price',
#  'Weight (Kilograms)',
#  'Freight Cost (USD)',
#  'Line Item Insurance (USD)',
#  'Country_Encoded']

# %%
qual
# Out:
# ['Country',
#  'Managed By',
#  'Fulfill Via',
#  'Vendor INCO Term',
#  'Shipment Mode',
#  'Product Group',
#  'First Line Designation']

# %%
descriptive = pd.DataFrame(index=['mean','median','mode','Q1:25%','Q2:50%','Q3:75%','Q4:100%','IQR','1.5rule','lesser','greater','min','max'], columns=quan)

# Assuming 'dataset' is your DataFrame
for ColumnName in quan:
    descriptive.loc['mean', ColumnName] = data[ColumnName].mean()
    descriptive.loc['median', ColumnName] = data[ColumnName].median()
    descriptive.loc['mode', ColumnName] = data[ColumnName].mode()[0]
    descriptive.loc['Q1:25%', ColumnName] = data[ColumnName].quantile(0.25)
    descriptive.loc['Q2:50%', ColumnName] = data[ColumnName].quantile(0.50)
    descriptive.loc['Q3:75%', ColumnName] = data[ColumnName].quantile(0.75)
    descriptive.loc['99%', ColumnName] = np.percentile(data[ColumnName], 99)
    descriptive.loc['Q4:100%', ColumnName] = data[ColumnName].max()
    descriptive.loc['IQR', ColumnName] = descriptive.loc['Q3:75%', ColumnName] - descriptive.loc['Q1:25%', ColumnName]
    descriptive.loc['1.5rule', ColumnName] = 1.5 * descriptive.loc['IQR', ColumnName]
    descriptive.loc['lesser', ColumnName] = descriptive.loc['Q1:25%', ColumnName] - descriptive.loc['1.5rule', ColumnName]
    descriptive.loc['greater', ColumnName] = descriptive.loc['Q3:75%', ColumnName] + descriptive.loc['1.5rule', ColumnName]
    descriptive.loc['min', ColumnName] = data[ColumnName].min()
    descriptive.loc['max', ColumnName] = data[ColumnName].max()

descriptive
# Out:
#         Unit of Measure (Per Pack) Line Item Quantity Line Item Value  \
# mean                     69.297172       11163.178528   105691.204373
# median                        60.0             3000.0       30471.465
# mode                            60          41987.375    409645.96125
# Q1:25%                        30.0              408.0       4314.5925
# Q2:50%                        60.0             3000.0       30471.465
# Q3:75%                        90.0           17039.75       166447.14
# Q4:100%                        180          41987.375    409645.96125
# IQR                           60.0           16631.75     162132.5475
# 1.5rule                       90.0          24947.625    243198.82125
# lesser                       -60.0         -24539.625   -238884.22875
# greater                      180.0          41987.375    409645.96125
# min                              1                1.0             0.0
# max                            180          41987.375    409645.96125
# 99%                          180.0          41987.375    409645.96125
#
#         Pack Price Unit Price Weight (Kilograms) Freight Cost (USD)  \
# mean     16.305778   0.320711        1272.446896         6398.18075
# median         9.3       0.16             1047.0           5869.655
# mode      52.80125      1.055             1047.0           5869.655
# Q1:25%        4.12       0.08              617.0          4323.8075
# Q2:50%         9.3       0.16             1047.0           5869.655
# Q3:75%     23.5925       0.47             1596.5            7707.64
# Q4:100%   52.80125      1.055            3065.75        12783.38875
# IQR        19.4725       0.39              979.5          3383.8325
# 1.5rule   29.20875      0.585            1469.25         5075.74875
# lesser   -25.08875     -0.505            -852.25         -751.94125
# greater   52.80125      1.055            3065.75        12783.38875
# min            0.0        0.0                0.0               0.75
# max       52.80125      1.055            3065.75        12783.38875
# 99%       52.80125      1.055            3065.75        12783.38875
#
#         Line Item Insurance (USD) Country_Encoded
# mean                   155.372139       27.480531
# median                      47.04            30.0
# mode                       593.83              33
# Q1:25%                       7.03            16.0
# Q2:50%                      47.04            30.0
# Q3:75%                     241.75            39.0
# Q4:100%                    593.83              42
# IQR                        234.72            23.0
# 1.5rule                    352.08            34.5
# lesser                    -345.05           -18.5
# greater                    593.83            73.5
# min                           0.0               0
# max                        593.83              42
# 99%                        593.83            42.0

# %%
lesser=[]
greater=[]

for columnName in quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName] ["max"]>descriptive[columnName]["greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %% [markdown]
# #  Statistical Summary

# %%
def Univariate(data,quan):
    descriptive = pd.DataFrame(index=['mean','median','mode','Q1:25%','Q2:50%','Q3:75%','Q4:100%','IQR','1.5rule',
                                      'lesser','greater','min','max','skew','kurtosis'], columns=quan)

    for ColumnName in quan:
        descriptive.loc['mean', ColumnName] = dataset[ColumnName].mean()
        descriptive.loc['median', ColumnName] = dataset[ColumnName].median()
        descriptive.loc['mode', ColumnName] = dataset[ColumnName].mode()[0]
        descriptive.loc['Q1:25%', ColumnName] = dataset[ColumnName].quantile(0.25)
        descriptive.loc['Q2:50%', ColumnName] = dataset[ColumnName].quantile(0.50)
        descriptive.loc['Q3:75%', ColumnName] = dataset[ColumnName].quantile(0.75)
        descriptive.loc['99%', ColumnName] = np.percentile(dataset[ColumnName], 99)
        descriptive.loc['Q4:100%', ColumnName] = dataset[ColumnName].max()
        descriptive.loc['IQR', ColumnName] = descriptive.loc['Q3:75%', ColumnName] - descriptive.loc['Q1:25%', ColumnName]
        descriptive.loc['1.5rule', ColumnName] = 1.5 * descriptive.loc['IQR', ColumnName]
        descriptive.loc['lesser', ColumnName] = descriptive.loc['Q1:25%', ColumnName] - descriptive.loc['1.5rule', ColumnName]
        descriptive.loc['greater', ColumnName] = descriptive.loc['Q3:75%', ColumnName] + descriptive.loc['1.5rule', ColumnName]
        descriptive.loc['min', ColumnName] = dataset[ColumnName].min()
        descriptive.loc['max', ColumnName] = dataset[ColumnName].max()
        descriptive.loc['skew', ColumnName]=dataset[ColumnName].skew()
        descriptive.loc['kurtosis', ColumnName]=dataset[ColumnName].kurtosis()
        descriptive.loc['var', ColumnName]=dataset[ColumnName].var()
        descriptive.loc['std', ColumnName]=dataset[ColumnName].std()

    return descriptive

# %%
descriptive
# Out:
#         Unit of Measure (Per Pack) Line Item Quantity Line Item Value  \
# mean                     69.297172       11163.178528   105691.204373
# median                        60.0             3000.0       30471.465
# mode                            60          41987.375    409645.96125
# Q1:25%                        30.0              408.0       4314.5925
# Q2:50%                        60.0             3000.0       30471.465
# Q3:75%                        90.0           17039.75       166447.14
# Q4:100%                        180          41987.375    409645.96125
# IQR                           60.0           16631.75     162132.5475
# 1.5rule                       90.0          24947.625    243198.82125
# lesser                       -60.0         -24539.625   -238884.22875
# greater                      180.0          41987.375    409645.96125
# min                              1                1.0             0.0
# max                            180          41987.375    409645.96125
# 99%                          180.0          41987.375    409645.96125
#
#         Pack Price Unit Price Weight (Kilograms) Freight Cost (USD)  \
# mean     16.305778   0.320711        1272.446896         6398.18075
# median         9.3       0.16             1047.0           5869.655
# mode      52.80125      1.055             1047.0           5869.655
# Q1:25%        4.12       0.08              617.0          4323.8075
# Q2:50%         9.3       0.16             1047.0           5869.655
# Q3:75%     23.5925       0.47             1596.5            7707.64
# Q4:100%   52.80125      1.055            3065.75        12783.38875
# IQR        19.4725       0.39              979.5          3383.8325
# 1.5rule   29.20875      0.585            1469.25         5075.74875
# lesser   -25.08875     -0.505            -852.25         -751.94125
# greater   52.80125      1.055            3065.75        12783.38875
# min            0.0        0.0                0.0               0.75
# max       52.80125      1.055            3065.75        12783.38875
# 99%       52.80125      1.055            3065.75        12783.38875
#
#         Line Item Insurance (USD) Country_Encoded
# mean                   155.372139       27.480531
# median                      47.04            30.0
# mode                       593.83              33
# Q1:25%                       7.03            16.0
# Q2:50%                      47.04            30.0
# Q3:75%                     241.75            39.0
# Q4:100%                    593.83              42
# IQR                        234.72            23.0
# 1.5rule                    352.08            34.5
# lesser                    -345.05           -18.5
# greater                    593.83            73.5
# min                           0.0               0
# max                        593.83              42
# 99%                        593.83            42.0

# %%
def freqTable(columnName,data):
    freqTable=pd.DataFrame(columns=['unique_values','frequency','Relative frequency','cusum'])
    freqTable['unique_values']=data[columnName].value_counts().index
    freqTable['frequency']=data[columnName].value_counts().values
    freqTable['Relative frequency']=(freqTable['frequency']/103)
    freqTable['cusum']=freqTable['Relative frequency'].cumsum()
    return freqTable

# %%
freqTable('Freight Cost (USD)',data)
# Out:
#       unique_values  frequency  Relative frequency       cusum
# 0        5869.65500       4126           40.058252   40.058252
# 1       12783.38875       1752           17.009709   57.067961
# 2        9736.10000         36            0.349515   57.417476
# 3        6147.18000         27            0.262136   57.679612
# 4        7445.80000         16            0.155340   57.834951
# ...             ...        ...                 ...         ...
# 3919     3701.66000          1            0.009709  100.194175
# 3920     7211.04000          1            0.009709  100.203883
# 3921    11252.53000          1            0.009709  100.213592
# 3922     7208.11000          1            0.009709  100.223301
# 3923     3410.00000          1            0.009709  100.233010
#
# [3924 rows x 4 columns]

# %%
freqTable('Weight (Kilograms)',data)
# Out:
#       unique_values  frequency  Relative frequency       cusum
# 0           1047.00       3952           38.368932   38.368932
# 1           3065.75       1713           16.631068   55.000000
# 2              2.00         29            0.281553   55.281553
# 3              6.00         26            0.252427   55.533981
# 4              1.00         23            0.223301   55.757282
# ...             ...        ...                 ...         ...
# 1864        2042.00          1            0.009709  100.194175
# 1865         676.00          1            0.009709  100.203883
# 1866         791.00          1            0.009709  100.213592
# 1867        2210.00          1            0.009709  100.223301
# 1868        1392.00          1            0.009709  100.233010
#
# [1869 rows x 4 columns]

# %% [markdown]
# # Basic Univariate Analysis

# %%
data.columns
# Out:
# Index(['Country', 'Managed By', 'Fulfill Via', 'Vendor INCO Term',
#        'Shipment Mode', 'Product Group', 'Unit of Measure (Per Pack)',
#        'Line Item Quantity', 'Line Item Value', 'Pack Price', 'Unit Price',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)', 'Country_Encoded'],
#       dtype='object')

# %%
from scipy import stats

# %%
cost=data['Freight Cost (USD)']
cost
# Out:
# 0          780.34000
# 1         4521.50000
# 2         1653.78000
# 3        12783.38875
# 4        12783.38875
#             ...
# 10319     5869.65500
# 10320     5869.65500
# 10321     5869.65500
# 10322     5869.65500
# 10323     5869.65500
# Name: Freight Cost (USD), Length: 10324, dtype: float64

# %%
meanc=cost.mean()
medianc=cost.median()
modec=cost.mode().iloc[0]
skewc=stats.skew(cost)
kurtosis=stats.kurtosis(cost)
std=cost.std()
variance=cost.var()

# %%
print("Mean Value",meanc)
print("Median Value",medianc)
print("Mode Value",modec)
print("Skewness Value",skewc)
print("kurtosis Value",kurtosis)
print("Standard Deviation Value",std)
print("Variance value",variance)
# Out:
# Mean Value 6398.180749709415
# Median Value 5869.655000000001
# Mode Value 5869.655000000001
# Skewness Value 0.4636414695094392
# kurtosis Value -0.6059745433097516
# Standard Deviation Value 3697.1069776084273
# Variance value 13668600.00388092

# %% [markdown]
# # As the kurtosis is less than it is platykurtic

# %%
import seaborn as sns

# %%
fig, axes = plt.subplots(1,2, figsize=(14, 6))
sns.histplot(cost, bins=10, kde=True, ax=axes[0], color='green')
axes[0].axvline(meanc, color='red', linestyle='--', label='Mean')
axes[0].axvline(medianc, color='green', linestyle='--', label='Median')
axes[0].axvline(modec, color='purple', linestyle='--', label='Mode')
axes[0].set_title(f'Histogram of revenue \nSkewness: {skewc:.2f}')
axes[0].set_xlabel('revenue')
axes[0].set_ylabel('Frequency')
axes[0].legend()

sns.histplot(cost, bins=10, kde=True, ax=axes[1], color='skyblue')
axes[1].axvline(meanc, color='red', linestyle='--', label='Mean')
axes[1].axvline(medianc, color='green', linestyle='--', label='Median')
axes[1].axvline(modec, color='purple', linestyle='--', label='Mode')
axes[1].set_title(f'Histogram of revenue \nKurtosis: {kurtosis:.2f}')
axes[1].set_xlabel('revenue')
axes[1].set_ylabel('Frequency')
axes[1].legend()

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# #   Normal Distribution

# %%
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(cost, bins=10, kde=False, color='skyblue', stat="density", alpha=0.6)

# Generate the x values for the normal distribution curve
x = np.linspace(cost.min(), cost.max(), 100)
# Calculate the normal distribution curve
y = stats.norm.pdf(x, meanc, std)

# Plot the normal distribution curve
plt.plot(x, y, color='red', label='Normal Distribution', linewidth=2)

# Add titles and labels
plt.title('Normal Distribution of Revenue ')
plt.xlabel('revenue')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Check lowest and Highest cost

# %%
# Lowest cost
low_cost = data['Freight Cost (USD)'].min()
print("Lowest cost Value:", low_cost)

# Highest revenue
high_cost = data['Freight Cost (USD)'].max()
print("Highest cost Value:", high_cost)
# Out:
# Lowest cost Value: 0.75
# Highest cost Value: 12783.388750000002

# %% [markdown]
# # Probability Density Function

# %%
# Define the range for filtering
lower_bound = 7000
upper_bound = 10000

# Calculate the percentage of values within the specified range
filtered_data = cost[(cost >= lower_bound) & (cost <= upper_bound)]
percentage_in_range = (len(filtered_data) / len(cost)) * 100

sns.set(style="whitegrid")

# Create the figure for KDE
plt.figure(figsize=(10, 6))

# Plot the KDE for the Probability Density Function in the specified range
sns.kdeplot(cost, color='blue', fill=True, alpha=0.3, label='Overall Distribution')
sns.kdeplot(filtered_data, color='orange', fill=True, alpha=0.6, label='Filtered Range (7k to 10k)')

# Add vertical lines for the range
plt.axvline(lower_bound, color='green', linestyle='--', label='Lower Bound (60)')
plt.axvline(upper_bound, color='red', linestyle='--', label='Upper Bound (70)')

# Add titles and labels
plt.title('Probability Density Function of revenue with Range Highlight')
plt.xlabel('revenue')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a bar plot for percentage representation
plt.figure(figsize=(6, 4))
plt.bar(['Within 60-70', 'Outside 60-70'], [percentage_in_range, 100 - percentage_in_range], color=['orange', 'lightblue'])
plt.title('Percentage of revenue  in Range (60 to 70)')
plt.ylabel('Percentage')
plt.ylim(0, 100)

# Show the percentage value on top of the bars
for index, value in enumerate([percentage_in_range, 100 - percentage_in_range]):
    plt.text(index, value + 1, f'{value:.2f}%', ha='center')

# Show the bar plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Standard Normal Distribution

# %%
from scipy.stats import norm

mean = np.mean(cost)
std_dev = np.std(cost)

# Standardize the  ratings
standardized_data = (cost - mean) / std_dev

# Create a range of values for plotting the standard normal distribution
x_values = np.linspace(-4, 4, 100)  # Range for the standard normal distribution
y_values = norm.pdf(x_values, 0, 1)  # PDF for standard normal distribution

# Set the style for the plots
sns.set(style="whitegrid")

# Create the figure
plt.figure(figsize=(10, 6))

# Plot the standardized data's histogram
sns.histplot(standardized_data, bins=10, kde=True, color='skyblue', stat='density', label='Standardized revenue')

# Plot the standard normal distribution curve
plt.plot(x_values, y_values, color='red', label='Standard Normal Distribution', lw=2)

# Add titles and labels
plt.title('Standard Normal Distribution of revenue')
plt.xlabel('Standardized revenue')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
# Revenue distribution
sns.histplot(data['Freight Cost (USD)'], kde=True, bins=10)
plt.title('Cost Distribution')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\MOHANLAL\anaconda3\envs\aiml\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# #  Covariance

# %%
data.cov()
# Out:
#                             Unit of Measure (Per Pack)  Line Item Quantity  \
# Unit of Measure (Per Pack)                2.154594e+03       -1.668738e+05
# Line Item Quantity                       -1.668738e+05        2.247325e+08
# Line Item Value                          -1.066839e+06        1.648040e+09
# Pack Price                                1.557393e+02       -8.332098e+04
# Unit Price                               -4.237807e+00       -1.332053e+03
# Weight (Kilograms)                       -3.921934e+03        9.795280e+06
# Freight Cost (USD)                       -6.309242e+03        2.290129e+07
# Line Item Insurance (USD)                -1.553341e+03        2.365654e+06
# Country_Encoded                          -5.133985e+01        3.242727e+04
#
#                             Line Item Value     Pack Price   Unit Price  \
# Unit of Measure (Per Pack)    -1.066839e+06     155.739265    -4.237807
# Line Item Quantity             1.648040e+09  -83320.980265 -1332.053456
# Line Item Value                1.938972e+10  101547.801485  2435.428970
# Pack Price                     1.015478e+05     268.663521     4.218948
# Unit Price                     2.435429e+03       4.218948     0.111170
# Weight (Kilograms)             8.526749e+07   -3110.522674   -49.484207
# Freight Cost (USD)             2.554933e+08    -580.838011    -4.624261
# Line Item Insurance (USD)      2.756163e+07     135.878767     3.278648
# Country_Encoded                2.234670e+05     -16.518370    -0.336100
#
#                             Weight (Kilograms)  Freight Cost (USD)  \
# Unit of Measure (Per Pack)       -3.921934e+03       -6.309242e+03
# Line Item Quantity                9.795280e+06        2.290129e+07
# Line Item Value                   8.526749e+07        2.554933e+08
# Pack Price                       -3.110523e+03       -5.808380e+02
# Unit Price                       -4.948421e+01       -4.624261e+00
# Weight (Kilograms)                9.623496e+05        2.473523e+06
# Freight Cost (USD)                2.473523e+06        1.366860e+07
# Line Item Insurance (USD)         1.228336e+05        3.647799e+05
# Country_Encoded                   1.787146e+03        3.391945e+03
#
#                             Line Item Insurance (USD)  Country_Encoded
# Unit of Measure (Per Pack)              -1.553341e+03       -51.339850
# Line Item Quantity                       2.365654e+06     32427.267141
# Line Item Value                          2.756163e+07    223467.004987
# Pack Price                               1.358788e+02       -16.518370
# Unit Price                               3.278648e+00        -0.336100
# Weight (Kilograms)                       1.228336e+05      1787.146416
# Freight Cost (USD)                       3.647799e+05      3391.944848
# Line Item Insurance (USD)                4.141762e+04       318.526639
# Country_Encoded                          3.185266e+02       136.697189

# %% [markdown]
# # Covariance

# %%
# Select only numeric columns
data.corr()
# Out:
#                             Unit of Measure (Per Pack)  Line Item Quantity  \
# Unit of Measure (Per Pack)                    1.000000           -0.239813
# Line Item Quantity                           -0.239813            1.000000
# Line Item Value                              -0.165056            0.789494
# Pack Price                                    0.204697           -0.339092
# Unit Price                                   -0.273819           -0.266498
# Weight (Kilograms)                           -0.086129            0.666066
# Freight Cost (USD)                           -0.036765            0.413204
# Line Item Insurance (USD)                    -0.164434            0.775400
# Country_Encoded                              -0.094600            0.185011
#
#                             Line Item Value  Pack Price  Unit Price  \
# Unit of Measure (Per Pack)        -0.165056    0.204697   -0.273819
# Line Item Quantity                 0.789494   -0.339092   -0.266498
# Line Item Value                    1.000000    0.044492    0.052456
# Pack Price                         0.044492    1.000000    0.771979
# Unit Price                         0.052456    0.771979    1.000000
# Weight (Kilograms)                 0.624211   -0.193447   -0.151289
# Freight Cost (USD)                 0.496286   -0.009585   -0.003751
# Line Item Insurance (USD)          0.972583    0.040734    0.048318
# Country_Encoded                    0.137261   -0.086195   -0.086217
#
#                             Weight (Kilograms)  Freight Cost (USD)  \
# Unit of Measure (Per Pack)           -0.086129           -0.036765
# Line Item Quantity                    0.666066            0.413204
# Line Item Value                       0.624211            0.496286
# Pack Price                           -0.193447           -0.009585
# Unit Price                           -0.151289           -0.003751
# Weight (Kilograms)                    1.000000            0.682005
# Freight Cost (USD)                    0.682005            1.000000
# Line Item Insurance (USD)             0.615259            0.484815
# Country_Encoded                       0.155817            0.078471
#
#                             Line Item Insurance (USD)  Country_Encoded
# Unit of Measure (Per Pack)                  -0.164434        -0.094600
# Line Item Quantity                           0.775400         0.185011
# Line Item Value                              0.972583         0.137261
# Pack Price                                   0.040734        -0.086195
# Unit Price                                   0.048318        -0.086217
# Weight (Kilograms)                           0.615259         0.155817
# Freight Cost (USD)                           0.484815         0.078471
# Line Item Insurance (USD)                    1.000000         0.133867
# Country_Encoded                              0.133867         1.000000

# %%
# Correlation heatmap for numerical columns
numerical_cols = ['Unit of Measure (Per Pack)', 'Line Item Quantity', 'Line Item Value', 'Pack Price',
                  'Unit Price', 'Weight (Kilograms)', 'Freight Cost (USD)',
                  'Line Item Insurance (USD)', 'Country_Encoded']

corr_matrix = data[numerical_cols].corr()

plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title('Correlation Matrix')
plt.show()

# %%
data.columns
# Out:
# Index(['Country', 'Managed By', 'Fulfill Via', 'Vendor INCO Term',
#        'Shipment Mode', 'Product Group', 'Unit of Measure (Per Pack)',
#        'Line Item Quantity', 'Line Item Value', 'Pack Price', 'Unit Price',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)', 'Country_Encoded'],
#       dtype='object')

# %%
# Average revenue by location
country_cost = data.groupby('Country')['Freight Cost (USD)'].mean().sort_values(ascending=False).head(5)
print(country_cost)

# Plot
country_cost.plot(kind='bar', color='pink')
plt.title('Top 10 countries')
plt.xlabel('Country')
plt.ylabel('Average cost')
plt.show()
# Out:
# Country
# Cameroon        8845.708500
# Nigeria         8513.029611
# Kenya           8144.695394
# Sierra Leone    8079.424688
# Ghana           7794.395474
# Name: Freight Cost (USD), dtype: float64

# %%
# Count of restaurants by cuisine
Country_count = data['Country'].value_counts()
# print(Country_count)

# Plot
Country_count.plot(kind='bar', color='orange')
plt.title('Count of Countries')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %%
ship_mode = data.groupby('Shipment Mode')['Freight Cost (USD)'].mean().sort_values(ascending=False)

# Plot bar chart
plt.figure(figsize=(10, 5))
ship_mode.plot(kind='bar', color='skyblue', edgecolor='black')

# Title and labels
plt.title('Average Freight Cost by Shipment Mode')
plt.xlabel('Shipment Mode')
plt.ylabel('Average Freight Cost (USD)')
plt.xticks(rotation=45)  # Rotate labels for better readability

# Show the plot
plt.show()
